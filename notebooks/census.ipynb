# %%
import requests

# %%
import requests
x = requests.get('https://api.data.abs.gov.au/data/ABS,RES_DWELL/1..Q?startPeriod=2019-Q4&endPeriod=2020-Q1&format=jsondata')
print(x)
# Out:
# <Response [200]>

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
data = x.text
parse_json = json.loads(data)
parse_json
# Out:
# {'meta': {'schema': 'https://raw.githubusercontent.com/sdmx-twg/sdmx-json/master/data-message/tools/schemas/1.0/sdmx-json-data-schema.json',
#   'id': 'IREF014347',
#   'prepared': '2022-09-05T15:21:09Z',
#   'test': False,
#   'contentLanguages': ['en'],
#   'sender': {'id': '_Stat_V8', 'name': 'unknown', 'names': {'en': 'unknown'}}},
#  'data': {'dataSets': [{'action': 'Information',
#     'links': [{'urn': 'urn:sdmx:org.sdmx.infomodel.datastructure.DataStructure=ABS:RES_DWELL(1.0.0)',
#       'rel': 'DataStructure'}],
#     'annotations': [0, 1, 2, 3, 4, 5],
#     'series': {'0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [9111, 0, None], '1': [8422, 0, None]}},
#      '0:1:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [877, 0, None], '1': [780, 0, None]}},
#      '0:2:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1616], '1': [1706]}},
#      '0:3:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [15628, 0, None], '1': [11236, 0, None]}},
#      '0:4:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [6858, 0, None], '1': [5968, 0, None]}},
#      '0:5:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [76], '1': [65]}},
#      '0:6:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1321, 0, None], '1': [1035, 0, None]}},
#      '0:7:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [8429, 0, None], '1': [7602, 0, None]}},
#      '0:8:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [4215], '1': [3624, 0, None]}},
#      '0:9:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [239], '1': [221]}},
#      '0:10:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1578], '1': [1368]}},
#      '0:11:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [6229, 0, None], '1': [5782]}},
#      '0:12:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [12304, 0, None], '1': [10125, 0, None]}},
#      '0:13:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [13545], '1': [9996, 0, None]}},
#      '0:14:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1734], '1': [1637, 0, None]}}}}],
#   'structure': {'name': 'Residential Dwellings: Unstratified Medians and Transfer Counts by Dwelling Type, GCCSA and Rest of State',
#    'names': {'en': 'Residential Dwellings: Unstratified Medians and Transfer Counts by Dwelling Type, GCCSA and Rest of State'},
#    'description': "Price indexes for established houses and attached dwellings as well as an aggregated residential property price index. Estimates of changes in residential property prices and the total value of Australia's dwelling stock, and preliminary housing market activity data. Provides estimates of changes in residential property prices in each of the eight capital cities of Australia. Unit of measure: AUD/Number. Geographic coverage: Australia/State/GCCSA. Catalogue number: 6416.0",
#    'descriptions': {'en': "Price indexes for established houses and attached dwellings as well as an aggregated residential property price index. Estimates of changes in residential property prices and the total value of Australia's dwelling stock, and preliminary housing market activity data. Provides estimates of changes in residential property prices in each of the eight capital cities of Australia. Unit of measure: AUD/Number. Geographic coverage: Australia/State/GCCSA. Catalogue number: 6416.0"},
#    'dimensions': {'dataset': [],
#     'series': [{'id': 'MEASURE',
#       'name': 'Measure',
#       'names': {'en': 'Measure'},
#       'keyPosition': 0,
#       'roles': ['MEASURE'],
#       'values': [{'id': '1',
#         'order': 0,
#         'name': 'Number of Established House Transfers',
#         'names': {'en': 'Number of Established House Transfers'},
#         'annotations': [6]}]},
#      {'id': 'REGION',
#       'name': 'Region',
#       'names': {'en': 'Region'},
#       'keyPosition': 1,
#       'roles': ['REGION'],
#       'values': [{'id': '3RQLD',
#         'order': 9,
#         'name': 'Rest of Qld',
#         'names': {'en': 'Rest of Qld'},
#         'parent': '3',
#         'annotations': [7]},
#        {'id': '6GHOB',
#         'order': 17,
#         'name': 'Greater Hobart',
#         'names': {'en': 'Greater Hobart'},
#         'parent': '6',
#         'annotations': [8]},
#        {'id': '6RTAS',
#         'order': 18,
#         'name': 'Rest of Tas.',
#         'names': {'en': 'Rest of Tas.'},
#         'parent': '6',
#         'annotations': [9]},
#        {'id': '2GMEL',
#         'order': 5,
#         'name': 'Greater Melbourne',
#         'names': {'en': 'Greater Melbourne'},
#         'parent': '2',
#         'annotations': [10]},
#        {'id': '2RVIC',
#         'order': 6,
#         'name': 'Rest of Vic.',
#         'names': {'en': 'Rest of Vic.'},
#         'parent': '2',
#         'annotations': [11]},
#        {'id': '7RNTE',
#         'order': 21,
#         'name': 'Rest of NT',
#         'names': {'en': 'Rest of NT'},
#         'parent': '7',
#         'annotations': [12]},
#        {'id': '8ACTE',
#         'order': 23,
#         'name': 'Australian Capital Territory',
#         'names': {'en': 'Australian Capital Territory'},
#         'parent': '8',
#         'annotations': [13]},
#        {'id': '3GBRI',
#         'order': 8,
#         'name': 'Greater Brisbane',
#         'names': {'en': 'Greater Brisbane'},
#         'parent': '3',
#         'annotations': [14]},
#        {'id': '4GADE',
#         'order': 11,
#         'name': 'Greater Adelaide',
#         'names': {'en': 'Greater Adelaide'},
#         'parent': '4',
#         'annotations': [15]},
#        {'id': '7GDAR',
#         'order': 20,
#         'name': 'Greater Darwin',
#         'names': {'en': 'Greater Darwin'},
#         'parent': '7',
#         'annotations': [16]},
#        {'id': '4RSAU',
#         'order': 12,
#         'name': 'Rest of SA',
#         'names': {'en': 'Rest of SA'},
#         'parent': '4',
#         'annotations': [17]},
#        {'id': '5GPER',
#         'order': 14,
#         'name': 'Greater Perth',
#         'names': {'en': 'Greater Perth'},
#         'parent': '5',
#         'annotations': [18]},
#        {'id': '1RNSW',
#         'order': 3,
#         'name': 'Rest of NSW',
#         'names': {'en': 'Rest of NSW'},
#         'parent': '1',
#         'annotations': [19]},
#        {'id': '1GSYD',
#         'order': 2,
#         'name': 'Greater Sydney',
#         'names': {'en': 'Greater Sydney'},
#         'parent': '1',
#         'annotations': [20]},
#        {'id': '5RWAU',
#         'order': 15,
#         'name': 'Rest of WA',
#         'names': {'en': 'Rest of WA'},
#         'parent': '5',
#         'annotations': [21]}]},
#      {'id': 'FREQ',
#       'name': 'Frequency',
#       'names': {'en': 'Frequency'},
#       'keyPosition': 2,
#       'roles': ['FREQ'],
#       'values': [{'id': 'Q',
#         'order': 8,
#         'name': 'Quarterly',
#         'names': {'en': 'Quarterly'}}]}],
#     'observation': [{'id': 'TIME_PERIOD',
#       'name': 'Time Period',
#       'names': {'en': 'Time Period'},
#       'keyPosition': 3,
#       'roles': ['TIME_PERIOD'],
#       'values': [{'start': '2019-10-01T00:00:00Z',
#         'end': '2019-12-31T00:00:00Z',
#         'id': '2019-Q4',
#         'name': '2019-Q4',
#         'names': {'en': '2019-Q4'}},
#        {'start': '2020-01-01T00:00:00Z',
#         'end': '2020-03-31T00:00:00Z',
#         'id': '2020-Q1',
#         'name': '2020-Q1',
#         'names': {'en': '2020-Q1'}}]}]},
#    'attributes': {'dataSet': [],
#     'series': [{'id': 'UNIT_MEASURE',
#       'name': 'Unit of Measure',
#       'names': {'en': 'Unit of Measure'},
#       'roles': ['UNIT_MEASURE'],
#       'relationship': {'dimensions': ['MEASURE']},
#       'values': [{'id': 'NUM',
#         'order': 1,
#         'name': 'Number',
#         'names': {'en': 'Number'}}],
#       'annotations': [22]},
#      {'id': 'UNIT_MULT',
#       'name': 'Unit of Multiplier',
#       'names': {'en': 'Unit of Multiplier'},
#       'roles': ['UNIT_MULT'],
#       'relationship': {'dimensions': ['MEASURE']},
#       'values': [{'id': '0',
#         'order': 0,
#         'name': 'Units',
#         'names': {'en': 'Units'}}],
#       'annotations': [23]}],
#     'observation': [{'id': 'OBS_STATUS',
#       'name': 'Observation Status',
#       'names': {'en': 'Observation Status'},
#       'roles': ['OBS_STATUS'],
#       'relationship': {'primaryMeasure': 'OBS_VALUE'},
#       'values': [{'id': 'r',
#         'order': 7,
#         'name': 'revised',
#         'names': {'en': 'revised'}}]},
#      {'id': 'OBS_COMMENT',
#       'name': 'Observation Comment',
#       'names': {'en': 'Observation Comment'},
#       'roles': ['OBS_COMMENT'],
#       'relationship': {'primaryMeasure': 'OBS_VALUE'},
#       'values': []}]},
#    'annotations': [{'type': 'NonProductionDataflow',
#      'text': 'true',
#      'texts': {'en': 'true'}},
#     {'title': 'REGION', 'type': 'LAYOUT_COLUMN'},
#     {'title': 'TIME_PERIOD', 'type': 'LAYOUT_ROW'},
#     {'title': 'MEASURE', 'type': 'LAYOUT_ROW_SECTION'},
#     {'title': 'FREQ=Q,TIME_PERIOD_START=2020-Q1', 'type': 'DEFAULT'},
#     {'type': 'EXT_RESOURCE',
#      'text': 'Methodology|https://www.abs.gov.au/statistics/economy/price-indexes-and-inflation/residential-property-price-indexes-eight-capital-cities/latest-release#methodology|https://www.abs.gov.au/ausstats/wmdata.nsf/activeimages/methodology/$File/methodology.png',
#      'texts': {'en': 'Methodology|https://www.abs.gov.au/statistics/economy/price-indexes-and-inflation/residential-property-price-indexes-eight-capital-cities/latest-release#methodology|https://www.abs.gov.au/ausstats/wmdata.nsf/activeimages/methodology/$File/methodology.png'}},
#     {'type': 'ORDER', 'text': '1', 'texts': {'en': '1'}},
#     {'type': 'ORDER', 'text': '10', 'texts': {'en': '10'}},
#     {'type': 'ORDER', 'text': '18', 'texts': {'en': '18'}},
#     {'type': 'ORDER', 'text': '19', 'texts': {'en': '19'}},
#     {'type': 'ORDER', 'text': '6', 'texts': {'en': '6'}},
#     {'type': 'ORDER', 'text': '7', 'texts': {'en': '7'}},
#     {'type': 'ORDER', 'text': '22', 'texts': {'en': '22'}},
#     {'type': 'ORDER', 'text': '24', 'texts': {'en': '24'}},
#     {'type': 'ORDER', 'text': '9', 'texts': {'en': '9'}},
#     {'type': 'ORDER', 'text': '12', 'texts': {'en': '12'}},
#     {'type': 'ORDER', 'text': '21', 'texts': {'en': '21'}},
#     {'type': 'ORDER', 'text': '13', 'texts': {'en': '13'}},
#     {'type': 'ORDER', 'text': '15', 'texts': {'en': '15'}},
#     {'type': 'ORDER', 'text': '4', 'texts': {'en': '4'}},
#     {'type': 'ORDER', 'text': '3', 'texts': {'en': '3'}},
#     {'type': 'ORDER', 'text': '16', 'texts': {'en': '16'}},
#     {'type': 'CONTEXT',
#      'text': 'If a unit multiplier exists the data is recorded according to the combination of the unit multiplier and the unit of measure.',
#      'texts': {'en': 'If a unit multiplier exists the data is recorded according to the combination of the unit multiplier and the unit of measure.'}},
#     {'type': 'CONTEXT',
#      'text': 'Codes for unit of multiplier are the exponent in base 10 so that multiplying the observation by 10^UNIT_MULT gives a value expressed in the unit of measure.',
#      'texts': {'en': 'Codes for unit of multiplier are the exponent in base 10 so that multiplying the observation by 10^UNIT_MULT gives a value expressed in the unit of measure.'}}]}}}

# %%
test = parse_json["dataSets"]
df = pd.DataFrame(test)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/hexiangyi/Desktop/generic-buy-now-pay-later-project-group-16-project2-fighting-group/notebooks/census.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/hexiangyi/Desktop/generic-buy-now-pay-later-project-group-16-project2-fighting-group/notebooks/census.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> test = parse_json["dataSets"]
#       <a href='vscode-notebook-cell:/Users/hexiangyi/Desktop/generic-buy-now-pay-later-project-group-16-project2-fighting-group/notebooks/census.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df = pd.DataFrame(test)
#       <a href='vscode-notebook-cell:/Users/hexiangyi/Desktop/generic-buy-now-pay-later-project-group-16-project2-fighting-group/notebooks/census.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> df
#
# KeyError: 'dataSets'
