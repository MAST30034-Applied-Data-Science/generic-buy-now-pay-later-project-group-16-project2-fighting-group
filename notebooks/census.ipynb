# %%
import requests

# %%
import requests

x = requests.get('https://www.abs.gov.au/statistics/standards/australian-statistical-geography-standard-asgs-edition-3/jul2021-jun2026/access-and-downloads/correspondences')

print(x)
# Out:
# <Response [200]>

# %%
import json
data = response.text
parse_json = json.loads(data)

# %%
import json
data = response.text
parse_json = json.loads(data)
#activate_case = parse_json[]

# %%
json_data = parse_json['data']
json_data
# Out:
# {'dataSets': [{'action': 'Information',
#    'links': [{'urn': 'urn:sdmx:org.sdmx.infomodel.datastructure.DataStructure=ABS:RES_DWELL(1.0.0)',
#      'rel': 'DataStructure'}],
#    'annotations': [0, 1, 2, 3, 4, 5],
#    'series': {'0:0:0': {'attributes': [0, 0],
#      'annotations': [],
#      'observations': {'0': [9338],
#       '1': [8501],
#       '2': [8156],
#       '3': [8893],
#       '4': [10211],
#       '5': [9672],
#       '6': [12211],
#       '7': [10119],
#       '8': [8729],
#       '9': [9551],
#       '10': [9204],
#       '11': [9206],
#       '12': [8195],
#       '13': [8791],
#       '14': [8934],
#       '15': [11050],
#       '16': [7811],
#       '17': [8663],
#       '18': [9665],
#       '19': [8885],
#       '20': [8665],
#       '21': [9680],
#       '22': [10071],
#       '23': [10805],
#       '24': [10484],
#       '25': [10900],
#       '26': [11019],
#       '27': [11864],
#       '28': [10929],
#       '29': [12124],
#       '30': [12705],
# ...
